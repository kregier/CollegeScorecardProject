# %% [markdown]
# # The Final Model
# - Resample the data (using the technique identified in the MultipleResamplingMethods notebook)
# - Run the Decision Tree Model follow by an AdaBoost model
# - Examine the results

# %%
# Set up the environment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
# %matplotlib inline

# %% [markdown]
# # Upload the (cleaned) data

# %%
data = pd.read_csv('../data/processed/DecisionTreeDataFinal.csv', index_col=0)
data.sort_index(inplace=True)
data.head()
# Out:
#       OPEID                                   INSTNM      CITY  NUMBRANCH  \
# 0  02295000                  everest college-phoenix   Phoenix          2
# 1  01293700     empire beauty school-paradise valley   Phoenix          1
# 2  00886500              empire beauty school-tucson    Tucson          2
# 3  00107000  thunderbird school of global management  Glendale          1
# 4  01084700             arizona automotive institute  Glendale          1
#
#    PREDDEG  HIGHDEG  CONTROL  region  ADM_RATE    UGDS  ...  NetPrice  \
# 0        1        3        3     6.0    0.4465  5662.0  ...   26004.0
# 1        1        1        3     6.0       NaN    86.0  ...   13026.0
# 2        1        1        3     6.0       NaN   149.0  ...   11915.0
# 3        1        4        2     6.0       NaN     2.0  ...   14996.0
# 4        1        1        3     6.0       NaN  1734.0  ...   24082.0
#
#       Cost    PREDDEG_N          Governance  EnrollmentBins  TuitionBins  \
# 0  29445.0  Certificate  Private for-profit              xl      highest
# 1  34124.0  Certificate  Private for-profit           small         high
# 2  35121.0  Certificate  Private for-profit           small         high
# 3  19623.0  Certificate   Private nonprofit           small      highest
# 4  40920.0  Certificate  Private for-profit           large         high
#
#    ExpenditureBins  Complete  RetentionFT  RetentionPT
# 0             high    0.4075      0.43330       0.0000
# 1          highest    0.4800      0.60870       0.2500
# 2             high    0.7025      0.50000       0.7619
# 3          highest    0.7500      0.74085          NaN
# 4              low    0.5725      0.58750          NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Separate the school identity information
# This can be merged with the results later, to link model predictions with school names.

# %%
identity = data[['OPEID','INSTNM', 'CITY', 'Governance', 'PREDDEG_N']]
identity.shape
# Out:
# (10200, 5)

# %% [markdown]
# ## Separate the closed schools from the database
# Explore the counts and distrubtion of the closed schools, and resample to balance the database.

# %%
closed = data.loc[data.CURROPER == False]
closed.shape
# Out:
# (2759, 32)

# %%
closed.PREDDEG_N.value_counts()
# Out:
# Certificate       1841
# Associates         325
# Not classified     253
# Bachelor           241
# Graduate            99
# Name: PREDDEG_N, dtype: int64

# %%
closed_degree = closed.pivot_table(index='PREDDEG_N', columns=['CONTROL'], aggfunc='size')
print(closed_degree)
# Out:
# CONTROL           1    2     3
# PREDDEG_N
# Associates       42   26   257
# Bachelor         13   94   134
# Certificate     117  147  1577
# Graduate          1   40    58
# Not classified   27   35   191

# %%
# Resample the minority class
from sklearn.utils import resample
closed_upsample = resample(closed, replace=True, n_samples=closed.shape[0]*2, random_state=123)

# %% [markdown]
# ## Separate the currently operating school and filter by year

# %%
open_df = data.loc[data.CURROPER==True]
open_df.shape
# Out:
# (7441, 32)

# %%
current = open_df.loc[data.Year > 2012]
current.shape
# Out:
# (7441, 32)

# %%
current.PREDDEG_N.value_counts()
# Out:
# Certificate       3093
# Bachelor          2101
# Associates        1488
# Not classified     473
# Graduate           286
# Name: PREDDEG_N, dtype: int64

# %%
current_degree = current.pivot_table(index='PREDDEG_N', columns=['CONTROL'], aggfunc='size')
print(current_degree)
# Out:
# CONTROL           1     2     3
# PREDDEG_N
# Associates      780   163   545
# Bachelor        588  1241   272
# Certificate     594   199  2300
# Graduate         15   236    35
# Not classified   75    89   309

# %% [markdown]
# ## Merge the filtered open schools with the upsampled closed schools

# %%
df = pd.concat([current, closed_upsample], axis = 0)
df.shape
# Out:
# (12959, 32)

# %%
df.CURROPER.value_counts()
# Out:
# True     7441
# False    5518
# Name: CURROPER, dtype: int64

# %%
df.head()
# Out:
#       OPEID                               INSTNM        CITY  NUMBRANCH  \
# 2396  Other             alabama a & m university      Normal          1
# 2397  Other  university of alabama at birmingham  Birmingham          1
# 2398  Other                   amridge university  Montgomery          1
# 2399  Other  university of alabama in huntsville  Huntsville          1
# 2400  Other             alabama state university  Montgomery          1
#
#       PREDDEG  HIGHDEG  CONTROL  region  ADM_RATE     UGDS  ...  NetPrice  \
# 2396        3        4        1     5.0    0.8989   4051.0  ...   13415.0
# 2397        3        4        1     5.0    0.8673  11200.0  ...   14805.0
# 2398        3        4        2     5.0       NaN    322.0  ...    7455.0
# 2399        3        4        1     5.0    0.8062   5525.0  ...   17520.0
# 2400        3        4        1     5.0    0.5125   5354.0  ...   11936.0
#
#          Cost  PREDDEG_N         Governance  EnrollmentBins  TuitionBins  \
# 2396  18888.0   Bachelor             Public              xl         high
# 2397  19990.0   Bachelor             Public              xl         high
# 2398  12300.0   Bachelor  Private nonprofit          medium      highest
# 2399  20306.0   Bachelor             Public              xl         high
# 2400  17400.0   Bachelor             Public              xl         high
#
#       ExpenditureBins  Complete  RetentionFT  RetentionPT
# 2396             high    0.2914       0.6314       0.5000
# 2397          highest    0.5377       0.8016       0.5000
# 2398              med    0.6667       0.3750       0.3333
# 2399             high    0.4835       0.8098       0.4444
# 2400             high    0.2517       0.6219       0.3023
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Basic EDA with the resampled and filtered data

# %%
df['PREDDEG_N'].value_counts()
# Out:
# Certificate       6762
# Bachelor          2595
# Associates        2126
# Not classified     979
# Graduate           497
# Name: PREDDEG_N, dtype: int64

# %%
print(df.Governance.value_counts())
# Out:
# Private for-profit    7845
# Private nonprofit     2646
# Public                2468
# Name: Governance, dtype: int64

# %%
control_degree = df.pivot_table(index='PREDDEG_N', columns=['CONTROL','CURROPER'], aggfunc='size')
print(control_degree)
# Out:
# CONTROL            1           2           3
# CURROPER       False True  False True  False True
# PREDDEG_N
# Associates        88   780    60   163   490   545
# Bachelor          21   588   179  1241   294   272
# Certificate      247   594   313   199  3109  2300
# Graduate           5    15    95   236   111    35
# Not classified    55    75    71    89   380   309

# %% [markdown]
# ## Drop columns not needed for analysis

# %%
to_drop = ['OPEID', 'INSTNM', 'CITY', 'HIGHDEG', 'ADM_RATE', 'NetPrice', 'region','EnrollmentBins','Governance',\
           'TuitionBins','ExpenditureBins', 'AVGFACSAL', 'RetentionPT', 'PCTFLOAN', 'Year', 'PREDDEG_N',\
          'COMP_ORIG_YR4_RT', 'WDRAW_ORIG_YR4_RT','ENRL_ORIG_YR4_RT']
df = df.drop(to_drop, axis=1)
df.head()
# Out:
#       NUMBRANCH  PREDDEG  CONTROL     UGDS  CURROPER  TUITFTE  INEXPFTE  \
# 2396          1        3        1   4051.0      True   9063.0    7459.0
# 2397          1        3        1  11200.0      True   9033.0   17208.0
# 2398          1        3        2    322.0      True  12057.0    5123.0
# 2399          1        3        1   5525.0      True   8322.0    9352.0
# 2400          1        3        1   5354.0      True   7813.0    7393.0
#
#       PFTFAC  UG25abv  DEBT_MDN     Cost  Complete  RetentionFT
# 2396  0.8856   0.1049   19500.0  18888.0    0.2914       0.6314
# 2397  0.9106   0.2422   16250.0  19990.0    0.5377       0.8016
# 2398  0.6721   0.8540   10500.0  12300.0    0.6667       0.3750
# 2399  0.6555   0.2640   16500.0  20306.0    0.4835       0.8098
# 2400  0.6641   0.1270   15854.5  17400.0    0.2517       0.6219

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12959 entries, 2396 to 778
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NUMBRANCH    12959 non-null  int64
#  1   PREDDEG      12959 non-null  int64
#  2   CONTROL      12959 non-null  int64
#  3   UGDS         12959 non-null  float64
#  4   CURROPER     12959 non-null  bool
#  5   TUITFTE      12959 non-null  float64
#  6   INEXPFTE     12959 non-null  float64
#  7   PFTFAC       12959 non-null  float64
#  8   UG25abv      12959 non-null  float64
#  9   DEBT_MDN     12959 non-null  float64
#  10  Cost         12959 non-null  float64
#  11  Complete     12959 non-null  float64
#  12  RetentionFT  12959 non-null  float64
# dtypes: bool(1), float64(9), int64(3)
# memory usage: 1.3 MB

# %%
df.isnull().sum()
# Out:
# NUMBRANCH      0
# PREDDEG        0
# CONTROL        0
# UGDS           0
# CURROPER       0
# TUITFTE        0
# INEXPFTE       0
# PFTFAC         0
# UG25abv        0
# DEBT_MDN       0
# Cost           0
# Complete       0
# RetentionFT    0
# dtype: int64

# %% [markdown]
# ## Split data into training and testing sets.

# %%
y = df.CURROPER
X = df.drop('CURROPER', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=21, stratify=y)

# %%
X_test.shape
# Out:
# (3888, 12)

# %% [markdown]
# # Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

# %% [markdown]
# ## Explore the criterion and max_depth hyperparameters
#
# Code modified from https://towardsdatascience.com/decision-tree-build-prune-and-visualize-it-using-python-12ceee9af752

# %%
from sklearn import metrics
max_depth = []
acc_gini = []
acc_entropy = []
for i in range(1, 31):
    gtree = DecisionTreeClassifier(criterion='gini', max_depth=i, random_state=21)
    gtree.fit(X_train, y_train)
    gpredict = gtree.predict(X_test)
    acc_gini.append(metrics.accuracy_score(y_test, gpredict))
    ##
    etree = DecisionTreeClassifier(criterion='entropy', max_depth=i, random_state=21)
    etree.fit(X_train, y_train)
    epredict = etree.predict(X_test)
    acc_entropy.append(metrics.accuracy_score(y_test, epredict))
    ##
    max_depth.append(i)

# %%
gini_max = max(acc_gini)
gini_idx = acc_gini.index(gini_max)
entropy_max = max(acc_entropy)
entropy_idx = acc_entropy.index(entropy_max)

if gini_max > entropy_max:
    depth = max_depth[gini_idx]
    crit = 'gini'
else:
    depth = max_depth[entropy_idx]
    crit='entropy'
    
print(depth)
# Out:
# 22

# %%
trees = pd.DataFrame({'acc_gini':pd.Series(acc_gini),
                     'acc_entropy':pd.Series(acc_entropy),
                     'max_depth':pd.Series(max_depth)})

plt.plot('max_depth', 'acc_gini', data=trees, label='gini')
plt.plot('max_depth', 'acc_entropy', data=trees, label='entropy')

plt.vlines(depth, 0.65, 0.88, linestyle = '--')
#plt.annotate('Optimal depth', xy = (16, .973))
#plt.annotate('= 13', xy = (16, .97))
plt.xlabel('Depth')
plt.ylabel('Accuracy')
plt.title('Decision Tree Hyperparameters')
plt.legend()
#plt.show()
plt.savefig('../figures/DTHyperparameters.png')

# %% [markdown]
# ## Run the Decision Tree model using the identified hyperparameters

# %%
# Initialize and fit the model
modelDT = DecisionTreeClassifier(criterion=crit, max_depth=depth, random_state=21)
modelDT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=22, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=21, splitter='best')

# %%
# Use the trained tree to predict the testing data
dt_pred = modelDT.predict(X_test)
dt_pred_prob = modelDT.predict_proba(X_test)

# %% [markdown]
# ## Model evaluation metrics

# %%
print("Model Metrics")
print("Accuracy:", metrics.accuracy_score(y_test, dt_pred))
print("Balanced accuracy:", metrics.balanced_accuracy_score(y_test, dt_pred))
print('Precision score for "Yes"' , metrics.precision_score(y_test, dt_pred, pos_label = 1))
print('Recall score for "No"' , metrics.recall_score(y_test, dt_pred, pos_label = 0))
# Out:
# Model Metrics
# Accuracy: 0.8706275720164609
# Balanced accuracy: 0.8777368708119059
# Precision score for "Yes" 0.9377215189873418
# Recall score for "No" 0.9257246376811594

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, dt_pred))
# Out:
# [[1533  123]
#  [ 380 1852]]

# %%
print(classification_report(y_test, dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.80      0.93      0.86      1656
#         True       0.94      0.83      0.88      2232
#
#     accuracy                           0.87      3888
#    macro avg       0.87      0.88      0.87      3888
# weighted avg       0.88      0.87      0.87      3888

# %%
importances = modelDT.feature_importances_
indices = np.argsort(importances)[::-1]
names = [X_train.columns[i] for i in indices]

print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %s (%f)" % (f + 1, names[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature UGDS (0.148392)
# 2. feature CONTROL (0.122221)
# 3. feature UG25abv (0.119403)
# 4. feature Cost (0.092577)
# 5. feature INEXPFTE (0.089737)
# 6. feature NUMBRANCH (0.086848)
# 7. feature DEBT_MDN (0.074328)
# 8. feature Complete (0.070672)
# 9. feature TUITFTE (0.068743)
# 10. feature RetentionFT (0.065013)
# 11. feature PFTFAC (0.040413)
# 12. feature PREDDEG (0.021651)

# %%
# Plot the impurity-based feature importances of the model
plt.figure()
fig=plt.bar(range(X.shape[1]), importances[indices],
        color="r", align="center")
plt.title("Feature importances: Decision Tree model")
plt.xticks(range(X.shape[1]), names, rotation=45, horizontalalignment='right')
plt.xlim([-1, X.shape[1]])
plt.savefig('../figures/DTFeatureImportance.png',bbox_inches='tight')

# %% [markdown]
# Enrollment (UGDS) is the most prominent feature that predicts open schools. Having higher enrollment increases the prediction that a school is currently operating.

# %% [markdown]
# ## Try various thresholds for the Decision Tree model

# %%
threshold = []
accurate=[]
balance_acc = []
pred_proba = []

for thresh in range(50, 100, 5):
    new_pred = []
    for i in range(0, len(dt_pred_prob)):
        # print(len(dt_pred_prob))
        new_pred.append(dt_pred_prob[i, 1] > (thresh / 100.0))
    # print(new_pred)
    accurate.append(metrics.accuracy_score(y_test, new_pred))
    balance_acc.append(metrics.balanced_accuracy_score(y_test, new_pred))
    threshold.append(thresh)
    pred_proba.append(new_pred)

# %%
print("Balance Accuracy: ", max(balance_acc))
idx = balance_acc.index(max(balance_acc))
print("Threshold: ", threshold[idx])
# Out:
# Balance Accuracy:  0.8780388031790556
# Threshold:  70

# %%
rate = pd.DataFrame({'threshold':pd.Series(threshold),
                     'accuracy':pd.Series(accurate),
                     'balance_acc':pd.Series(balance_acc)})

#fig = plt.figure(figsize = (8, 5))
plt.plot('threshold', 'accuracy', data=rate, label='accuracy')
plt.plot('threshold', 'balance_acc', data=rate, label='balanced accuracy')
plt.vlines(70, 0.868, 0.878, linestyle ='--')
plt.xlabel('Threshold')
plt.ylabel('Accuracy')
plt.title('Decision Tree Model')
plt.annotate('Threshold: 70', xy=(71, 0.874))
plt.annotate('Balanced accuracy: 0.878', xy=(71, 0.873))
plt.legend()
#plt.show()
plt.savefig('../figures/DTThreshold.png')

# %% [markdown]
# # AdaBoost model
# ## Explore the n_estimators hyperparameter

# %%
ABmax_depth = []
score_a = []
score_b = []

for i in range(105, 131, 1):
    atree = AdaBoostClassifier(n_estimators=i, random_state=21)
    atree.fit(X_train, y_train)
    apredict = gtree.predict(X_test)
    score_a.append(metrics.accuracy_score(y_test, apredict))
    ##
    btree = AdaBoostClassifier(modelDT, n_estimators=i, random_state=21)
    btree.fit(X_train, y_train)
    bpredict = btree.predict(X_test)
    score_b.append(metrics.accuracy_score(y_test, bpredict))
    ##
    ABmax_depth.append(i)

# %%
ideal_estimators = max(score_b)
idx = score_b.index(ideal_estimators)
print(ABmax_depth[idx])
# Out:
# 122

# %%
adatrees = pd.DataFrame({'score_a':pd.Series(score_a),
                     'score_b':pd.Series(score_b),
                     'n_estimators':pd.Series(ABmax_depth)})

plt.plot('n_estimators', 'score_a', data=adatrees, label='No_base')
plt.plot('n_estimators', 'score_b', data=adatrees, label='Base')
plt.vlines(ABmax_depth[idx], 0.85, 0.93, linestyle = '--')
plt.xlabel('Number of estimators')
plt.ylabel('Accuracy')
plt.legend()
plt.title('AdaBoost Hyperparameters')
#plt.show()
plt.savefig('../figures/ABHyperparameters.png')

# %% [markdown]
# ## Run the AdaBoost model using the identified hyperparameter

# %%
# Initialize and fit the model
modelAB = AdaBoostClassifier(modelDT, n_estimators=ABmax_depth[idx], random_state=21)
modelAB.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#                    base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                          class_weight=None,
#                                                          criterion='gini',
#                                                          max_depth=22,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          presort='deprecated',
#                                                          random_state=21,
#                                                          splitter='best'),
#                    learning_rate=1.0, n_estimators=122, random_state=21)

# %%
# Use the trained tree to predict the testing data
AB_pred = modelAB.predict(X_test)
AB_pred_prob = modelAB.predict_proba(X_test)

# %% [markdown]
# ## Model evaluation metrics

# %%
print("Model Metrics")
print("Accuracy:", metrics.accuracy_score(y_test, AB_pred))
print("Balanced accuracy:", metrics.balanced_accuracy_score(y_test, AB_pred))
print('Precision score for "Yes"' , metrics.precision_score(y_test, AB_pred, pos_label = 1))
print('Recall score for "No"' , metrics.recall_score(y_test, AB_pred, pos_label = 0))
# Out:
# Model Metrics
# Accuracy: 0.9194958847736625
# Balanced accuracy: 0.9206891849774037
# Precision score for "Yes" 0.9452436194895592
# Recall score for "No" 0.928743961352657

# %%
print(confusion_matrix(y_test, AB_pred))
# Out:
# [[1538  118]
#  [ 195 2037]]

# %%
print(classification_report(y_test, AB_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.89      0.93      0.91      1656
#         True       0.95      0.91      0.93      2232
#
#     accuracy                           0.92      3888
#    macro avg       0.92      0.92      0.92      3888
# weighted avg       0.92      0.92      0.92      3888

# %%
importances = modelAB.feature_importances_
std = np.std([tree.feature_importances_ for tree in modelAB.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]
names = [X_train.columns[i] for i in indices]

print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %s (%f)" % (f + 1, names[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature RetentionFT (nan)
# 2. feature Complete (nan)
# 3. feature Cost (nan)
# 4. feature DEBT_MDN (nan)
# 5. feature UG25abv (nan)
# 6. feature PFTFAC (nan)
# 7. feature INEXPFTE (nan)
# 8. feature TUITFTE (nan)
# 9. feature UGDS (nan)
# 10. feature PREDDEG (nan)
# 11. feature NUMBRANCH (nan)
# 12. feature CONTROL (0.001795)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/tree/_classes.py:578: RuntimeWarning: invalid value encountered in true_divide
#   return self.tree_.compute_feature_importances()

# %%
# Plot the feature importances of the model
plt.figure()
plt.title("Feature importances: AdaBoost model")
plt.bar(range(X.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), names, rotation=45, horizontalalignment='right')
plt.xlim([-1, X.shape[1]])
#plt.show()
plt.savefig('../figures/ABFeatureImportance.png',bbox_inches='tight')

# %% [markdown]
# ### Try various thresholds for AdaBoost model, too

# %%
AB_pred_prob = modelAB.predict_proba(X_test)

ABthreshold = []
ABaccurate=[]
ABbalance_acc = []
ABpred_proba = []

for thresh in range(50, 100, 5):
    new_pred = []
    for i in range(0, len(AB_pred_prob)):
        # print(len(dt_pred_prob))
        new_pred.append(AB_pred_prob[i, 1] > (thresh / 100.0))
    # print(new_pred)
    ABaccurate.append(metrics.accuracy_score(y_test, new_pred))
    ABbalance_acc.append(metrics.balanced_accuracy_score(y_test, new_pred))
    ABthreshold.append(thresh)
    ABpred_proba.append(new_pred)

# %%
print("Balance Accuracy: ", max(ABbalance_acc))
idx = ABbalance_acc.index(max(ABbalance_acc))
print("Threshold: ", ABthreshold[idx])
# Out:
# Balance Accuracy:  0.9206891849774037
# Threshold:  50

# %%
ABrate = pd.DataFrame({'threshold':pd.Series(ABthreshold),
                     'accuracy':pd.Series(ABaccurate),
                     'balance_acc':pd.Series(ABbalance_acc)})

plt.plot('threshold', 'accuracy', data=ABrate, label='accuracy')
plt.plot('threshold', 'balance_acc', data=ABrate, label='balanced accuracy')
#plt.vlines(6, 0.895, 0.915)
plt.xlabel('Threshold')
plt.ylabel('Accuracy')
plt.title('AdaBoost Model')
plt.annotate('Threshold: 50', xy=(50, 0.84))
plt.annotate('Balanced accuracy: 0.9207', xy=(50, 0.82))
plt.legend()
#plt.show()
plt.savefig('../figures/ABThreshold.png')

# %% [markdown]
# # Results
# We are interested in predicting schools that might be in danger of closing. This would be schools that are currently open, but that the model predicts are closed (a.k.a 'false negatives').

# %% [markdown]
# ## Put predicted results in a dataframe, and merge with identity data

# %%
# Record actual and predicted values for test set.
result_dict = {'CURROPER':y_test, 'Predicted':AB_pred, 'Probability':AB_pred_prob[:,1]}
results = pd.DataFrame(result_dict)

# %%
# Join actual and predicted values for test set to the features used by the model.
predicted = pd.concat([X_test, results], axis=1)
predicted.head()
# Out:
#       NUMBRANCH  PREDDEG  CONTROL    UGDS  TUITFTE  INEXPFTE  PFTFAC  UG25abv  \
# 9024         31        1        3   550.0  23376.0    6967.0  0.4298   0.5782
# 4792          1        1        3   270.0   5128.0    6008.0  0.4298   0.5444
# 5686          1        2        3   557.0   9465.0    3661.0  0.3235   0.5673
# 309           1        1        3   129.0   7651.0    8874.0  0.4298   0.6688
# 4898          1        2        1  3381.0   2635.0    5570.0  0.2457   0.2190
#
#       DEBT_MDN     Cost  Complete  RetentionFT  CURROPER  Predicted  \
# 9024   12380.5  18947.0    0.3721       0.6475      True       True
# 4792    4857.0  15973.0    0.5523       0.6552      True       True
# 5686    9500.0  22907.0    0.2300       0.6129      True      False
# 309    10885.0  38377.0    0.6124       0.6429     False      False
# 4898    5906.0  13481.0    0.3339       0.6095      True       True
#
#       Probability
# 9024     0.719276
# 4792     0.949661
# 5686     0.311707
# 309      0.003350
# 4898     0.999621

# %%
# Add a column labeling the results as TP, TN, FP or FN, for ease of access.
predicted['Result'] = np.nan
predicted.loc[(predicted.Predicted==True)&(predicted.CURROPER==True), 'Result'] = 'TP'
predicted.loc[(predicted.Predicted==False)&(predicted.CURROPER==False), 'Result'] = 'TN'
predicted.loc[(predicted.Predicted==True)&(predicted.CURROPER==False), 'Result'] = 'FP'
predicted.loc[(predicted.Predicted==False)&(predicted.CURROPER==True), 'Result'] = 'FN'
print(predicted.Result)
# Out:
# 9024    TP
# 4792    TP
# 5686    FN
# 309     TN
# 4898    TP
#         ..
# 6357    TP
# 2366    TN
# 6762    FN
# 1609    TN
# 8805    TP
# Name: Result, Length: 3888, dtype: object

# %%
# Explore schools that are closed, but predicted to be open
false_pos = predicted.loc[(predicted.Predicted == True) & (predicted.CURROPER == False)]
false_pos.shape
# Out:
# (118, 16)

# %%
# Explore schools that are currently operating, but predicted to be closed. These are the interesting cases.
false_neg = predicted.loc[(predicted.Predicted==False) & (predicted.CURROPER==True)]
false_neg.shape
# Out:
# (195, 16)

# %%
# Merge school name and identity information to the predictions
to_graph = predicted.merge(identity, how='left', left_index=True, right_index=True)
to_graph.head()
# Out:
#     NUMBRANCH  PREDDEG  CONTROL   UGDS  TUITFTE  INEXPFTE  PFTFAC  UG25abv  \
# 1           1        1        3   86.0   8740.0   10208.0  0.4298   0.3636
# 2           2        1        3  149.0   9033.0    7898.0  0.4298   0.1336
# 3           1        1        2    2.0  49859.0   33004.0  0.6301   0.5258
# 5           1        1        3  252.0   6997.0    3720.0  0.4298   0.4667
# 13          1        1        3  137.0   3629.0     596.0  0.4298   0.4637
#
#     DEBT_MDN     Cost  ...  RetentionFT  CURROPER  Predicted  Probability  \
# 1    10556.0  34124.0  ...      0.60870     False      False     0.002618
# 2     9864.5  35121.0  ...      0.50000     False      False     0.002891
# 3     9500.0  19623.0  ...      0.74085     False      False     0.001720
# 5    10570.0  23465.0  ...      0.87720     False      False     0.003315
# 13    5500.0  22707.0  ...      0.97620     False       True     0.922005
#
#     Result     OPEID                                   INSTNM        CITY  \
# 1       TN  01293700     empire beauty school-paradise valley     Phoenix
# 2       TN  00886500              empire beauty school-tucson      Tucson
# 3       TN  00107000  thunderbird school of global management    Glendale
# 5       TN  02561900            brillare hairdressing academy  Scottsdale
# 13      FP  02192300              maricopa beauty college llc    Avondale
#
#             Governance    PREDDEG_N
# 1   Private for-profit  Certificate
# 2   Private for-profit  Certificate
# 3    Private nonprofit  Certificate
# 5   Private for-profit  Certificate
# 13  Private for-profit  Certificate
#
# [5 rows x 21 columns]

# %%
to_graph.duplicated().sum()
# Out:
# 399

# %%
to_graph.drop_duplicates(inplace=True)
to_graph.shape
# Out:
# (3489, 21)

# %%
to_graph.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3489 entries, 1 to 10199
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NUMBRANCH    3489 non-null   int64
#  1   PREDDEG      3489 non-null   int64
#  2   CONTROL      3489 non-null   int64
#  3   UGDS         3489 non-null   float64
#  4   TUITFTE      3489 non-null   float64
#  5   INEXPFTE     3489 non-null   float64
#  6   PFTFAC       3489 non-null   float64
#  7   UG25abv      3489 non-null   float64
#  8   DEBT_MDN     3489 non-null   float64
#  9   Cost         3489 non-null   float64
#  10  Complete     3489 non-null   float64
#  11  RetentionFT  3489 non-null   float64
#  12  CURROPER     3489 non-null   bool
#  13  Predicted    3489 non-null   bool
#  14  Probability  3489 non-null   float64
#  15  Result       3489 non-null   object
#  16  OPEID        3489 non-null   object
#  17  INSTNM       3489 non-null   object
#  18  CITY         3489 non-null   object
#  19  Governance   3489 non-null   object
#  20  PREDDEG_N    3489 non-null   object
# dtypes: bool(2), float64(10), int64(3), object(6)
# memory usage: 552.0+ KB

# %% [markdown]
# ## Rerun evaluation metrics
# Since the closed schools were resampled before the model was trained, there were duplicated schools in the test set. Once those duplicates are dropped, we can rerun the model metrics to see how well the model performs on the non-duplicated data.

# %%
print(confusion_matrix(to_graph['CURROPER'], to_graph['Predicted']))
# Out:
# [[1164   93]
#  [ 195 2037]]

# %%
print(classification_report(to_graph['CURROPER'], to_graph['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.86      0.93      0.89      1257
#         True       0.96      0.91      0.93      2232
#
#     accuracy                           0.92      3489
#    macro avg       0.91      0.92      0.91      3489
# weighted avg       0.92      0.92      0.92      3489

# %% [markdown]
# ## Explore distribution of schools by predictions and features.

# %%
degreeControl = to_graph.pivot_table(index='PREDDEG_N', columns=['Governance','CURROPER'], aggfunc='size')
print(degreeControl)
# Out:
# Governance     Private for-profit        Private nonprofit        Public  \
# CURROPER                    False  True              False  True   False
# PREDDEG_N
# Associates                  114.0  174.0              13.0   56.0   21.0
# Bachelor                     72.0   79.0              43.0  362.0    3.0
# Certificate                 693.0  724.0              71.0   52.0   59.0
# Graduate                     30.0    5.0              20.0   80.0    NaN
# Not classified               82.0   79.0              19.0   34.0   17.0
#
# Governance
# CURROPER        True
# PREDDEG_N
# Associates      213.0
# Bachelor        169.0
# Certificate     178.0
# Graduate          4.0
# Not classified   23.0

# %%
predControl = to_graph.pivot_table(index='PREDDEG_N', columns=['Governance','Result'], aggfunc='size')
print(predControl)
# Out:
# Governance     Private for-profit                     Private nonprofit        \
# Result                         FN    FP     TN     TP                FN    FP
# PREDDEG_N
# Associates                   29.0   8.0  106.0  145.0               1.0   5.0
# Bachelor                      7.0   1.0   71.0   72.0               3.0  10.0
# Certificate                 126.0  50.0  643.0  598.0               6.0   4.0
# Graduate                      NaN   NaN   30.0    5.0               NaN   NaN
# Not classified               11.0   5.0   77.0   68.0               4.0   NaN
#
# Governance                  Public
# Result            TN     TP     FN   FP    TN     TP
# PREDDEG_N
# Associates       8.0   55.0    1.0  2.0  19.0  212.0
# Bachelor        33.0  359.0    NaN  2.0   1.0  169.0
# Certificate     67.0   46.0    6.0  5.0  54.0  172.0
# Graduate        20.0   80.0    NaN  NaN   NaN    4.0
# Not classified  19.0   30.0    1.0  1.0  16.0   22.0

# %%
controlPivot = to_graph.pivot_table(index='Governance', columns = 'Result', aggfunc='size')
print(controlPivot)
# Out:
# Result               FN  FP   TN   TP
# Governance
# Private for-profit  173  64  927  888
# Private nonprofit    14  19  147  570
# Public                8  10   90  579

# %%
false_neg = to_graph.loc[to_graph.Result == 'FN']
false_neg.shape
# Out:
# (195, 21)

# %% [markdown]
# # Results
# ## Explore predictions of various schools
# I know there are several private colleges whose name starts with 'Bethel', that are members of the potential client's organization. I'm going to explore the predictions made for schools with similar names, as a proxy for the client's member institutions.

# %%
bethel = data.loc[data['INSTNM'].str.startswith('bethel')]
bethel = bethel.copy()
bethel.shape
# Out:
# (11, 32)

# %%
bethel.CURROPER.value_counts()
# Out:
# True     7
# False    4
# Name: CURROPER, dtype: int64

# %%
## Run the Bethel schools through the model and see what it predicts
to_drop = ['OPEID', 'INSTNM', 'CITY', 'HIGHDEG', 'ADM_RATE', 'NetPrice', 'region','EnrollmentBins','Governance',\
           'TuitionBins','ExpenditureBins', 'AVGFACSAL', 'RetentionPT', 'PCTFLOAN', 'Year', 'PREDDEG_N',
          'COMP_ORIG_YR4_RT', 'WDRAW_ORIG_YR4_RT','ENRL_ORIG_YR4_RT']
bethel_test = bethel.drop(to_drop, axis=1)
bethel_test = bethel_test.drop('CURROPER', axis=1)

# %%
bethel_pred = modelAB.predict(bethel_test)
bethel_pred_prob = modelAB.predict_proba(bethel_test)

# %%
bethel['Predict'] = bethel_pred
bethel['Probability'] = bethel_pred_prob[:,1]
print(bethel[['INSTNM','CURROPER', 'Predict', 'Probability']].head(11))
# Out:
#                            INSTNM  CURROPER  Predict  Probability
# 350   bethel seminary of the east     False    False     0.002292
# 1228  bethel seminary of the east     False    False     0.002979
# 1953  bethel seminary of the east     False    False     0.003232
# 3582       bethel college-indiana      True     True     0.999652
# 3746  bethel college-north newton      True     True     0.991593
# 4298            bethel university      True     True     0.999689
# 4299      bethel seminary-st paul      True     True     0.996376
# 5978            bethel university      True     True     0.999862
# 6835    bethel seminary-san diego      True     True     0.996481
# 6987  bethel seminary of the east     False    False     0.026033
# 8986               bethel college      True     True     0.998635

# %% [markdown]
# ## Explore predictions for private nonprofit schools

# %%
nonprofit = data.loc[data.CONTROL==2]
nonprofit = nonprofit.copy()
nonprofit_test = nonprofit.drop(to_drop, axis=1)
nonprofit_test = nonprofit_test.drop('CURROPER', axis=1)
print(nonprofit.shape)
# Out:
# (2270, 32)

# %%
nonprofit_pred = modelAB.predict(nonprofit_test)
nonprofit_pred_prob = modelAB.predict_proba(nonprofit_test)

# %%
nonprofit['Predict'] =  nonprofit_pred
nonprofit['Probability'] = nonprofit_pred_prob[:,1]

# %%
sixty = nonprofit.loc[(nonprofit['Probability'] <0.6) & (nonprofit['Probability']>0.5)]
sixty = sixty.copy()
sixty.shape
# Out:
# (11, 34)

# %%
print(sixty[['INSTNM','CURROPER', 'Predict', 'Probability']].head(11))
# Out:
#                                                  INSTNM  CURROPER  Predict  \
# 1102                    rabbinical seminary m'kor chaim     False     True
# 1172                    remington college-dallas campus     False     True
# 1769                          florida christian college     False     True
# 1986                            icc technical institute     False     True
# 2674                                        cet-salinas      True     True
# 3518             national university of health sciences      True     True
# 4580  alegent creighton health school of radiologic ...      True     True
# 6093  baptist missionary association theological sem...      True     True
# 6648                   universidad teologica del caribe      True     True
# 8906               remington college of nursing orlando      True     True
# 9467                        annenberg school of nursing      True     True
#
#       Probability
# 1102     0.581587
# 1172     0.585063
# 1769     0.535063
# 1986     0.517349
# 2674     0.530625
# 3518     0.505836
# 4580     0.515314
# 6093     0.581713
# 6648     0.543585
# 8906     0.581263
# 9467     0.520239

# %% [markdown]
# ### Notes about schools with 50-60% predicted probability of being open.
# - CET-Salinas - still operating
# - National university of health sciences - still operating
# - Baptist Missionary Association Theological Seminary - still operating
# - Universidad teologica del caribe - academic calendar available for 2018-2019, COVID updates, so appears to be operating
# - Annenberg School of Nursing - appears to be operating.
#
# - Alegent creighton health school of radiologic - It is difficult to find information about this school, since there is no current institution website matching this name. This institution may have closed, changed name or merged with CHI Health.
# - Remington College of Nursing Orlando - Remington College exits, but without a nursing program. The College of Nursing may have been renamed or merged with ECPI University, St. Mary campus.

# %% [markdown]
# # Graphically explore the results
#
# ## UGDS - Undergraduate enrollment

# %%
fig=plt.figure(figsize=(10,4), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.boxplot('Governance', 'UGDS', data = to_graph, hue = 'Result')
plt.ylim(0, 20000)
plt.title('Enrollment by Governance')

plt.subplot(1, 2, 2)
sns.boxplot('PREDDEG_N', 'UGDS', data = to_graph, hue = 'Result')
plt.ylim(0, 10000)
plt.title('Enrollment by Degree Type')
plt.tight_layout()

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('TUITFTE', 'UGDS', data=to_graph.loc[to_graph.Predicted==True], hue = 'Governance',style='Result', alpha=0.5 )
plt.title('Predicted Positive')
plt.xlim(0,100000)
plt.ylim(0,20000)

plt.subplot(1, 2, 2)
sns.scatterplot('TUITFTE', 'UGDS', data=to_graph.loc[to_graph.Predicted==False], hue = 'Governance', style='Result', alpha=0.5)
plt.title('Predicted Negative')
plt.xlim(0,100000)
plt.ylim(0,20000)

plt.tight_layout()
fig.suptitle('Tuition Revenue by Enrollment')
#plt.savefig('../figures/ResultsTuitionEnrollmentControl.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Tuition Revenue by Enrollment')

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('TUITFTE', 'UGDS', data=to_graph.loc[to_graph.Predicted==True], hue='Result',style='Governance', size='Result', sizes={40, 20}, alpha=0.5)
plt.title('Predicted Positive')
plt.xlim(0,100000)
plt.ylim(0,20000)

plt.subplot(1, 2, 2)
sns.scatterplot('TUITFTE', 'UGDS', data=to_graph.loc[to_graph.Predicted==False], hue='Result', style='Governance',size='Result', sizes={20,40}, alpha=0.5)
plt.title('Predicted Negative')
plt.xlim(0,100000)
plt.ylim(0,20000)

plt.tight_layout()
fig.suptitle('Tuition Revenue by Enrollment')
#plt.savefig('../figures/ResultsTuitionEnrollment.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Tuition Revenue by Enrollment')

# %% [markdown]
# ## Tuition revenue and Cost

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('TUITFTE', 'Cost', data=to_graph.loc[to_graph.Predicted==True], hue ='Governance', style='Result', alpha=0.5)
plt.xlim(0, 80000)
plt.ylim(0, 80000)
plt.title('Predicted Positive')

plt.subplot(1, 2, 2)
sns.scatterplot('TUITFTE', 'Cost', data=to_graph.loc[to_graph.Predicted==False], hue = 'Governance', style='Result', alpha=0.5)
plt.xlim(0, 80000)
plt.ylim(0, 80000)
plt.title('Predicted Negative')

plt.tight_layout()
fig.suptitle('Tuition Revenue by Cost')
#plt.savefig('../figures/ResultsTuitionCostControl.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Tuition Revenue by Cost')

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('TUITFTE', 'Cost', data=to_graph.loc[to_graph.Predicted==True], hue ='Result', style='Governance', size='Result', sizes={20, 40}, alpha=0.5)
plt.xlim(0, 80000)
plt.ylim(0, 80000)
plt.title('Predicted Positive')

plt.subplot(1, 2, 2)
sns.scatterplot('TUITFTE', 'Cost', data=to_graph.loc[to_graph.Predicted==False], hue = 'Result', style='Governance', size='Result', sizes={20,40}, alpha=0.5)
plt.xlim(0, 80000)
plt.ylim(0, 80000)
plt.title('Predicted Negative')

plt.tight_layout()
fig.suptitle('Tuition Revenue by Cost')
#plt.savefig('../figures/ResultsTuitionCost.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Tuition Revenue by Cost')

# %% [markdown]
# ## Cost and Debt

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('Cost', 'DEBT_MDN', data=to_graph.loc[to_graph.Predicted==True], hue='Governance', style='CURROPER', alpha=0.5)
plt.title('Predicted Positive')
plt.ylim(0,30000)

plt.subplot(1, 2, 2)
sns.scatterplot('Cost', 'DEBT_MDN', data=to_graph.loc[to_graph.Predicted==False], hue='Governance', style='CURROPER', alpha=0.5)
plt.title('Predicted Negative')
plt.ylim(0,30000)

plt.tight_layout()
fig.suptitle('Median debt by Cost')
#plt.savefig('../figures/ResultsCostDebtControl.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Median debt by Cost')

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('Cost', 'DEBT_MDN', data=to_graph.loc[to_graph.Predicted==True], hue='Governance', style='Result', alpha=0.5)
plt.title('Predicted Positive')
plt.ylim(0,30000)
plt.xlim(0,60000)

plt.subplot(1, 2, 2)
sns.scatterplot('Cost', 'DEBT_MDN', data=to_graph.loc[to_graph.Predicted==False], hue='Governance', style='Result', alpha=0.5)
plt.title('Predicted Negative')
plt.ylim(0,30000)
plt.xlim(0,60000)

plt.tight_layout()
fig.suptitle('Median debt by Cost')
#plt.savefig('../figures/ResultsTuitionCostPositive.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Median debt by Cost')

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 2)
sns.scatterplot('Cost', 'DEBT_MDN', data=to_graph.loc[to_graph.Predicted==False], hue='Result', style='Governance', alpha=0.5)
plt.title('Predicted Negative')
plt.ylim(0,30000)
plt.xlim(0,60000)

plt.subplot(1, 2, 1)
sns.scatterplot('Cost', 'DEBT_MDN', data=to_graph.loc[to_graph.Predicted==True], hue='Result', style='Governance', alpha=0.5)
plt.title('PredictedPostive')
plt.ylim(0,30000)
plt.xlim(0,60000)


plt.tight_layout()
#plt.show()
#plt.savefig('../figures/ResultsTuitionCostNegative.png',bbox_inches='tight')

# %% [markdown]
# ## Number of Branches

# %%
to_graph.NUMBRANCH.hist(bins=25)

# %%
fig=plt.figure(figsize=(10,4), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.boxplot('Governance', 'NUMBRANCH', data = to_graph, hue = 'Result')
plt.title('Number of Branches by Control')

plt.subplot(1, 2, 2)
sns.boxplot('PREDDEG_N', 'NUMBRANCH', data = to_graph, hue = 'Result')
plt.title('Number of Branches by Degree Type')
plt.tight_layout()

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('NUMBRANCH', 'UGDS', data=to_graph.loc[to_graph.Predicted==True], hue='Result', style='Governance', alpha=0.5)
plt.title('Predicted Positive')

plt.subplot(1, 2, 2)
sns.scatterplot('NUMBRANCH', 'UGDS', data=to_graph.loc[to_graph.Predicted==False], hue='Result', style='Governance',size='Result', sizes={20,40}, alpha=0.5)
plt.title('Predicted Negative')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle('Number of branches by Enrollment')
# Out:
# Text(0.5, 0.98, 'Number of branches by Enrollment')

# %% [markdown]
# ## Instructional Expenditure

# %%
fig=plt.figure(figsize=(10,4), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.boxplot('Governance', 'INEXPFTE', data = to_graph, hue = 'Result')
plt.ylim(0, 100000)
plt.title('Instructional Expenditure by Control')

plt.subplot(1, 2, 2)
sns.boxplot('PREDDEG_N', 'INEXPFTE', data = to_graph, hue = 'Result')
plt.ylim(0, 100000)
plt.title('Instructional Expenditure by Degree Type')
plt.tight_layout()

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
#sns.scatterplot('', 'UGDS', data=to_graph, hue = 'Result')
sns.scatterplot('INEXPFTE', 'UGDS', data=to_graph.loc[to_graph.Predicted==True], hue='Result', style='Governance', alpha=0.5)
plt.xlim(0, 100000)
plt.ylim(0, 12000)
plt.title('Predicted Positive')

plt.subplot(1, 2, 2)
#sns.scatterplot('INEXPFTE', 'UGDS', data=to_graph.loc[to_graph.Result=='FN'], hue = 'CONTROL')
sns.scatterplot('INEXPFTE', 'UGDS', data=to_graph.loc[to_graph.Predicted==False], hue='Result', style='Governance',size='Result', sizes={20,40}, alpha=0.5)
plt.xlim(0, 100000)
plt.ylim(0, 12000)
plt.title('Predicted Negative')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle('Expenditure by Enrollment')
#plt.savefig('../figures/ResultsExpenditureUGDS.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Expenditure by Enrollment')

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('INEXPFTE', 'Cost', data=to_graph.loc[to_graph.Predicted==True], hue='Result', style='Governance',size='Result', sizes={20,40})#, alpha=0.5)
plt.ylim(0, 50000)
plt.title('Predicted Positive')

plt.subplot(1, 2, 2)
sns.scatterplot('INEXPFTE', 'Cost', data=to_graph.loc[to_graph.Predicted==False], hue = 'Result', style='Governance', size='Result', sizes={20,40})
plt.ylim(0, 50000)
plt.title('Predicted Negative')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle('Expenditure by Cost')
#plt.savefig('../figures/ResultsExpenditureCostPositive.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Expenditure by Cost')

# %% [markdown]
# ## Explore the bachelor's granting institutions from the test set.

# %%
bach = to_graph.loc[to_graph.PREDDEG==3]
bach = bach.copy()
bach.columns
# Out:
# Index(['NUMBRANCH', 'PREDDEG', 'CONTROL', 'UGDS', 'TUITFTE', 'INEXPFTE',
#        'PFTFAC', 'UG25abv', 'DEBT_MDN', 'Cost', 'Complete', 'RetentionFT',
#        'CURROPER', 'Predicted', 'Probability', 'Result', 'OPEID', 'INSTNM',
#        'CITY', 'Governance', 'PREDDEG_N'],
#       dtype='object')

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('Cost', 'DEBT_MDN', data=bach.loc[bach.Predicted==True], hue='Governance',size='Result', sizes={20,40}, alpha=0.5)
plt.title('PredictedPostive')
plt.ylim(0,30000)
plt.xlim(0,60000)

plt.subplot(1, 2, 2)
sns.scatterplot('Cost', 'DEBT_MDN', data=bach.loc[bach.Predicted==False], hue='Governance', size='Result', sizes={20,40}, alpha=0.5)
plt.title('Predicted Negative')
plt.ylim(0,30000)
plt.xlim(0,60000)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle("Bachelor's - Cost by Debt")
#plt.savefig('../figures/ResultsBachDebtCost.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, "Bachelor's - Cost by Debt")

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('TUITFTE', 'Cost', data=bach.loc[bach.Predicted==True], hue='Governance',style='Result', alpha=0.5 )
plt.xlim(0, 80000)
plt.ylim(0, 80000)
plt.title('Predicted Positive')

plt.subplot(1, 2, 2)
sns.scatterplot('TUITFTE', 'Cost', data=bach.loc[bach.Predicted==False], hue='Governance',style='Result',size='Result', sizes={20,40}, alpha=0.5)
plt.xlim(0, 80000)
plt.ylim(0, 80000)
plt.title('Predicted Negative')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle("Bachelor's - Tuition Revenue by Cost")
#plt.savefig('../figures/ResultsBachTuitionCost.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, "Bachelor's - Tuition Revenue by Cost")

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('TUITFTE', 'UGDS', data=bach.loc[bach.Predicted==True], hue = 'Governance',style='Result', alpha=0.5 )
plt.title('Predicted Positive')
plt.xlim(0,100000)
plt.ylim(0,20000)

plt.subplot(1, 2, 2)
sns.scatterplot('TUITFTE', 'UGDS', data=bach.loc[bach.Predicted==False], hue = 'Governance', style='Result', alpha=0.5)
plt.title('Predicted Negative')
plt.xlim(0,100000)
plt.ylim(0,20000)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle("Bachelor's - Tuition Revenue by Enrollment")
#plt.savefig('../figures/ResultsBachTuitionEnrollmentControl.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, "Bachelor's - Tuition Revenue by Enrollment")

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('Cost', 'DEBT_MDN', data=bach.loc[bach.Predicted==True], hue='Governance', style='Result', alpha=0.5)
plt.title('Predicted Positive')
plt.ylim(0,30000)
plt.xlim(0,60000)

plt.subplot(1, 2, 2)
sns.scatterplot('Cost', 'DEBT_MDN', data=bach.loc[bach.Predicted==False], hue='Governance', style='Result', alpha=0.5)
plt.title('Predicted Negative')
plt.ylim(0,30000)
plt.xlim(0,60000)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle("Bachelor's - Cost by Debt")
#plt.savefig('../figures/ResultsBachTuitionCostNegative.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, "Bachelor's - Cost by Debt")

# %%
dangerBachPrivate = bach.loc[(bach['CONTROL']==2) & (bach['Result']=='FN')]
dangerBachPrivate.shape
# Out:
# (3, 21)

# %%
dangerBachPrivate[['INSTNM', 'CITY', 'Governance', 'PREDDEG_N', 'CURROPER', 'Predicted', 'Probability']]
# Out:
#                                                  INSTNM          CITY  \
# 5194                              st andrews university    Laurinburg
# 8183  central methodist university-college of gradua...       Fayette
# 8422                        the robert b miller college  Battle Creek
#
#              Governance PREDDEG_N  CURROPER  Predicted  Probability
# 5194  Private nonprofit  Bachelor      True      False     0.258114
# 8183  Private nonprofit  Bachelor      True      False     0.252362
# 8422  Private nonprofit  Bachelor      True      False     0.440132

# %% [markdown]
# ### Notes on false negative, private nonprofit, bachelor's granting institutions.
# - St. Andrews University, Laurinburg - still operating in 2020
# - Central Methodist Univeristy - College of Graduate and Extended Studies, Fayette  - still operating in 2020
# - The Robert B Miller college, Battle Creek, MI - closed in 2016

# %%
fig=plt.figure(figsize=(10,5), dpi= 100, facecolor='w', edgecolor='k')
plt.subplot(1, 2, 1)
sns.scatterplot('Cost', 'DEBT_MDN', data=nonprofit.loc[nonprofit.Predict==True], hue='CURROPER',size='CURROPER', sizes={20,40}, alpha=0.5)
plt.title('PredictedPostive')
plt.ylim(0,30000)
plt.xlim(0,60000)

plt.subplot(1, 2, 2)
sns.scatterplot('Cost', 'DEBT_MDN', data=nonprofit.loc[nonprofit.Predict==False], hue='CURROPER', size='CURROPER', sizes={20,40}, alpha=0.5)
plt.title('Predicted Negative')
plt.ylim(0,30000)
plt.xlim(0,60000)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle("Private Nonprofit - Cost by Debt")
#plt.savefig('../figures/ResultsBachTuitionCostPositive.png',bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Private Nonprofit - Cost by Debt')
